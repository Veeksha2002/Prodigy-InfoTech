# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:/Internship/Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.shape
# Out:
# (200, 5)

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df['A']=df[['Annual Income (k$)']]
df['B']=df[['Spending Score (1-100)']]

# %%
x=df[['A','B']]
x.head()
# Out:
#     A   B
# 0  15  39
# 1  15  81
# 2  16   6
# 3  16  77
# 4  17  40

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(x['A'],x['B'],s=30,c='b')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
Kmean=KMeans(n_clusters=5)
Kmean.fit(x)
centers=Kmean.cluster_centers_
print(Kmean.cluster_centers_)
# Out:
# [[55.0875     49.7125    ]
#  [86.53846154 82.12820513]
#  [25.72727273 79.36363636]
#  [87.75       17.58333333]
#  [26.30434783 20.91304348]]

# %%
clusters=Kmean.fit_predict(x)
df['label']=clusters
df.head(10)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)   A  \
# 0           1    Male   19                  15                      39  15
# 1           2    Male   21                  15                      81  15
# 2           3  Female   20                  16                       6  16
# 3           4  Female   23                  16                      77  16
# 4           5  Female   31                  17                      40  17
# 5           6  Female   22                  17                      76  17
# 6           7  Female   35                  18                       6  18
# 7           8  Female   23                  18                      94  18
# 8           9    Male   64                  19                       3  19
# 9          10  Female   30                  19                      72  19
#
#     B  label
# 0  39      1
# 1  81      2
# 2   6      1
# 3  77      2
# 4  40      1
# 5  76      2
# 6   6      1
# 7  94      2
# ...

# %%
col=['blue','purple','maroon','black','salmon']
for i in range(5):
    a=col[i]
    plt.scatter(df.A[df.label==i],df.B[df.label==i],c=a,label='Cluster')
plt.scatter(centers[:,0],centers[:,1],marker='*',s=300,c='r',label='Centroid')

# %%
y=x.loc[:,['A','B']].values
y
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
wcss=[]
for j in range(1,11):
    kmeans=KMeans(n_clusters=j,init='k-means++')
    kmeans.fit(y)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,11),wcss,linewidth=2,color='indigo',marker='8')
plt.xlabel('K Value')
plt.ylabel('WCSS')
plt.show()
